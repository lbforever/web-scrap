# %%
import requests
req = requests.get('https://www.flipkart.com/search?q=Laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=off&as=off&as-pos=1&as-type=HISTORY&as-backfill=on%27')

# %%
from bs4 import BeautifulSoup
import pandas as pd
webpage = req.text
soup = BeautifulSoup(webpage, 'html.parser')

products=[] #List to store name of the product
prices=[] #List to store price of the product

for a in soup.findAll(attrs={'class':'_1fQZEK'}):
    name=a.find('div', attrs={'class':'_4rR01T'})
    price=a.find('div', attrs={'class':'_30jeq3 _1_WHN1'})
    products.append(name.text)
    prices.append(price.text)
    
df = pd.DataFrame({'Product Name':products,'Price':prices})
df.to_csv('products.csv', index=False, encoding='utf-8')
df
# Out:
#                                          Product Name      Price
# 0   HP 14s Intel Core i3 11th Gen - (8 GB/256 GB S...    ₹32,990
# 1   HP Ryzen 3 Dual Core 3250U - (8 GB/256 GB SSD/...    ₹27,123
# 2   ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...    ₹32,990
# 3   DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HD...    ₹38,990
# 4   Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...    ₹36,990
# 5   Lenovo Celeron Dual Core - (4 GB/256 GB HDD/25...    ₹19,990
# 6   HP Pavilion Ryzen 5 Hexa Core AMD R5-5600H - (...    ₹59,990
# 7   Lenovo IdeaPad 3 Chromebook Celeron Dual Core ...    ₹16,490
# 8   ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...    ₹49,990
# 9   acer Aspire 7 Core i5 12th Gen - (16 GB/512 GB...    ₹61,990
# 10  Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/256 ...    ₹31,990
# 11  GIGABYTE G5 MD Core i5 11th Gen - (16 GB/512 G...    ₹69,990
# 12  Infinix INBook X1 Neo Series Celeron Quad Core...    ₹24,999
# 13  ASUS TUF Gaming A15 Ryzen 5 Hexa Core AMD R5-4...    ₹59,990
# 14  acer Aspire 7 Ryzen 5 Hexa Core AMD R5-5500U -...    ₹47,990
# 15  acer Aspire 7 Ryzen 5 Hexa Core 5500U - (16 GB...    ₹51,990
# 16  GIGABYTE G5 GD Core i5 11th Gen - (16 GB/512 G...    ₹73,990
# 17  Infinix INBook X1 Core i5 10th Gen - (8 GB/512...    ₹37,990
# 18  HP G8 Core i3 11th Gen - (8 GB/512 GB SSD/Wind...    ₹34,999
# 19  APPLE 2021 Macbook Pro M1 Pro - (16 GB/512 GB ...  ₹1,81,990
# 20  DELL Ryzen 5 Hexa Core AMD R5-6600H - (16 GB/5...    ₹86,990
# 21  HP 15s Intel Core i3 11th Gen - (8 GB/512 GB S...    ₹39,999
# 22  Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U - (8 ...    ₹41,990
# 23  APPLE 2020 Macbook Air M1 - (8 GB/256 GB SSD/M...    ₹88,990
